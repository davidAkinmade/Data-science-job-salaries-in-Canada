# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('salary_data_clean.csv')

# %%
df.head(10)
# Out:
#                                            Job Title  \
# 0  Analytics Partner, Data Science and Analytics,...
# 1                                       Data Analyst
# 2                                      Data Engineer
# 3                              Data Engineer Analyst
# 4                          Machine Learning Engineer
# 5                                     Data Scientist
# 6                                    Research Intern
# 7              Analytics & Data Science Co-op/Intern
# 8                                Data Science Intern
# 9                             Educator, Data Science
#
#                    Salary Estimate  \
# 0  CA$73K-CA$105K (Glassdoor est.)
# 1  CA$73K-CA$105K (Glassdoor est.)
# 2  CA$73K-CA$105K (Glassdoor est.)
# 3  CA$73K-CA$105K (Glassdoor est.)
# 4  CA$73K-CA$105K (Glassdoor est.)
# 5  CA$73K-CA$105K (Glassdoor est.)
# 6  CA$73K-CA$105K (Glassdoor est.)
# 7  CA$73K-CA$105K (Glassdoor est.)
# 8  CA$73K-CA$105K (Glassdoor est.)
# 9  CA$73K-CA$105K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Listening to Albertans. Going deeper to unders...     3.6
# 1  Score Media & Gaming Inc. empowers millions of...     3.6
# 2  Apply Now\n\nData Engineer\n\nOttawa, ON, Cana...     4.2
# 3  This is an opportunity in the exciting and fas...     4.5
# 4  Machine Learning Engineer - Intermediate, and ...     4.6
# 5  The Analytic & Insights Group at The AIR MILES...    -1.0
# 6  To start the application process, you will nee...     4.4
# 7  Job Title\nAnalytics & Data Science Co-op/Inte...     3.9
# 8  Intelense being IBM business partner is focuse...    -1.0
# 9  Educator, Data Science\n\nBrainStation is a gl...     4.3
#
#          Company Name   Location       Headquarters                     Size  \
# 0  ATB Financial\n3.6    Calgary   Edmonton, Canada  5001 to 10000 employees
# 1       theScore\n3.6    Toronto    Toronto, Canada     201 to 500 employees
# 2       Ceridian\n4.2     Ottawa    Minneapolis, MN   1001 to 5000 employees
# 3         RideCo\n4.5   Waterloo   Waterloo, Canada                  Unknown
# 4         MavTek\n4.6   Montreal   Montreal, Canada      51 to 200 employees
# 5           AIR MILES    Toronto    Toronto, Canada    501 to 1000 employees
# 6         Google\n4.4    Toronto  Mountain View, CA         10000+ employees
# 7        TD Bank\n3.9    Toronto    Toronto, Canada         10000+ employees
# 8       Intelense Inc    Toronto                 -1                       -1
# 9   BrainStation\n4.3  Vancouver       New York, NY      51 to 200 employees
#
#    Founded  Type of ownership  ...      company_txt       hq_short same_state  \
# 0     1938  Company - Private  ...  ATB Financial\n       Edmonton          0
# 1     2012   Company - Public  ...       theScore\n        Toronto          1
# 2     1991   Company - Public  ...       Ceridian\n    Minneapolis          0
# 3       -1   Company - Public  ...         RideCo\n       Waterloo          1
# 4     2014  Company - Private  ...         MavTek\n       Montreal          1
# 5     1992  Company - Private  ...        AIR MILES        Toronto          1
# 6     1998   Company - Public  ...         Google\n  Mountain View          0
# 7     1855   Company - Public  ...        TD Bank\n        Toronto          1
# 8       -1                 -1  ...    Intelense Inc             -1          0
# 9     2012  Company - Private  ...   BrainStation\n       New York          0
#
#    age  python_yn  r_yn  aws_yn spark_yn excel_yn        job_simp
# 0   82          1     0       0        0        0              na
# 1    8          1     0       0        0        1         analyst
# 2   29          1     0       1        1        0   data engineer
# 3   -1          1     0       0        0        1   data engineer
# 4    6          1     0       1        1        0             mle
# 5   28          1     0       0        1        0  data scientist
# 6   22          1     0       0        0        0              na
# 7  165          1     0       0        0        1              na
# 8   -1          1     0       0        1        0              na
# 9    8          1     0       0        0        0              na
#
# [10 rows x 27 columns]

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'min_salary', 'max_salary', 'avg_salary', 'company_txt', 'hq_short',
#        'same_state', 'age', 'python_yn', 'r_yn', 'aws_yn', 'spark_yn',
#        'excel_yn'],
#       dtype='object')

# %%
def title_simplifier(title):
    if 'data scientist' in title.lower():
        return 'data scientist'
    elif 'data engineer' in title.lower():
        return 'data engineer'
    elif 'analyst' in title.lower():
        return 'analyst'
    elif 'machine learning' in title.lower():
        return 'mle'
    elif 'manager' in title.lower():
        return 'manager'
    elif 'director' in title.lower():
        return 'director'
    else:
        return 'na'
    
def seniority(title):
    if 'sr' in title.lower() or 'senior' in title.lower() or 'sr' in title.lower() or 'lead' in title.lower() or 'principal' in title.lower():
            return 'senior'
    elif 'jr' in title.lower() or 'jr.' or 'intern' in title.lower():
        return 'jr'
    else:
        return 'na'


#remove new line from job title

# %%
## Job title and seniority 
df['job_simp'] = df['Job Title'].apply(title_simplifier)

# %%
df['job_simp'].value_counts()
df[df['job_simp'] == 'na'].head(60)
# Out:
#                                              Job Title  \
# 0    Analytics Partner, Data Science and Analytics,...
# 6                                      Research Intern
# 7                Analytics & Data Science Co-op/Intern
# 8                                  Data Science Intern
# 9                               Educator, Data Science
# 10                                  Data Science Co-op
# 13                              Data Science Developer
# 24                 Applied Statistician - Data Science
# 35                             Data Science Consultant
# 36                                  Intern Talent Pool
# 42                                           Scientist
# 44   Associate Program (Paris/Montréal) - Data Science
# 45                          User Experience Researcher
# 55                          Imaging Research Associate
# 61                             Data Science Consultant
# 67   Data Developer, Monetization / Développeur de ...
# 73                 Data Science Team Lead - AlphaLayer
# 94                 Data Science Team Lead - AlphaLayer
# 99                      Data Science Customer Engineer
# 100              Software Engineer, Anti-Fraud Systems
# 103  Tenure-Track Assistant Professor in Statistics...
# 120  CRC Tier 2 - Artificial Intelligence for Compl...
# 146            AVP - Data Science and Client Analytics
# 153  Senior Product Owner, Portfolio Modelling and ...
# 164           Frontend Engineer (Developer Experience)
# 169                               QA Software Engineer
# 174                       Software Dev Eng I - Toronto
# 175                           Software Engineer - FEAR
# 181              Data Science 4 Month Co-op/Internship
# 183            Data Science- 4 months Co-op/Internship
# 194       Learn more about our Digital Analytics team!
# 202                             Data Platform Engineer
# 204  Amazon Web Services (RDS) - Software Developme...
# 210                              Battery Test Engineer
# 211          SaaS Developer & Data Science Opportunity
# 215                AWS - Big Data Architect, Analytics
# 222                             Data Science Team Lead
# 228  Statistical Programming Scientist ( (Home-Base...
# 241        Geophysicist - Signal Processing Specialist
# 242                                 Solutions Engineer
# 244                             Sr. Software Developer
# 247                             Data Platform Engineer
# 251  Biostatistician Precision Medicine (Personalis...
# 256  Amazon Web Services (RDS) - Software Developme...
# 261                              Insights&PerformSDEII
# 267                              Battery Test Engineer
# 270                         Quality Assurance Engineer
# 271          SaaS Developer & Data Science Opportunity
# 273                                 Clin Trials Asst 2
# 279                AWS - Big Data Architect, Analytics
# 280                        Clinical Trials Assistant 2
# 283              Python Backend Developer (Contractor)
# 289  Software Developer Engineer- Virtual Customer ...
# 290                             Data Science Team Lead
# 303  Statistical Programming Scientist ( (Home-Base...
# 305                     Correlation Software Developer
# 311                                          Architect
# 313                     Front End Software Developer -
# 316                                 Solutions Engineer
# 320  Student Intern - Data Analysis, Commodity Mana...
#
#                       Salary Estimate  \
# 0     CA$73K-CA$105K (Glassdoor est.)
# 6     CA$73K-CA$105K (Glassdoor est.)
# 7     CA$73K-CA$105K (Glassdoor est.)
# 8     CA$73K-CA$105K (Glassdoor est.)
# 9     CA$73K-CA$105K (Glassdoor est.)
# 10    CA$73K-CA$105K (Glassdoor est.)
# 13    CA$73K-CA$105K (Glassdoor est.)
# 24    CA$73K-CA$105K (Glassdoor est.)
# 35     CA$47K-CA$64K (Glassdoor est.)
# 36     CA$47K-CA$64K (Glassdoor est.)
# 42     CA$47K-CA$64K (Glassdoor est.)
# 44     CA$47K-CA$64K (Glassdoor est.)
# 45     CA$47K-CA$64K (Glassdoor est.)
# 55     CA$47K-CA$64K (Glassdoor est.)
# 61    CA$75K-CA$102K (Glassdoor est.)
# 67    CA$75K-CA$102K (Glassdoor est.)
# 73    CA$75K-CA$102K (Glassdoor est.)
# 94    CA$78K-CA$100K (Glassdoor est.)
# 99    CA$78K-CA$100K (Glassdoor est.)
# 100   CA$78K-CA$100K (Glassdoor est.)
# 103   CA$78K-CA$100K (Glassdoor est.)
# 120    CA$42K-CA$60K (Glassdoor est.)
# 146    CA$42K-CA$60K (Glassdoor est.)
# 153   CA$81K-CA$123K (Glassdoor est.)
# 164   CA$81K-CA$123K (Glassdoor est.)
# 169   CA$81K-CA$123K (Glassdoor est.)
# 174   CA$81K-CA$123K (Glassdoor est.)
# 175   CA$81K-CA$123K (Glassdoor est.)
# 181    CA$75K-CA$91K (Glassdoor est.)
# 183    CA$75K-CA$91K (Glassdoor est.)
# 194    CA$75K-CA$91K (Glassdoor est.)
# 202    CA$75K-CA$91K (Glassdoor est.)
# 204    CA$75K-CA$91K (Glassdoor est.)
# 210    CA$66K-CA$94K (Glassdoor est.)
# 211    CA$66K-CA$94K (Glassdoor est.)
# 215    CA$66K-CA$94K (Glassdoor est.)
# 222    CA$66K-CA$94K (Glassdoor est.)
# 228    CA$66K-CA$94K (Glassdoor est.)
# 241  CA$101K-CA$123K (Glassdoor est.)
# 242  CA$101K-CA$123K (Glassdoor est.)
# 244  CA$101K-CA$123K (Glassdoor est.)
# 247  CA$101K-CA$123K (Glassdoor est.)
# 251  CA$101K-CA$123K (Glassdoor est.)
# 256  CA$101K-CA$123K (Glassdoor est.)
# 261  CA$101K-CA$123K (Glassdoor est.)
# 267  CA$101K-CA$123K (Glassdoor est.)
# 270    CA$55K-CA$91K (Glassdoor est.)
# 271    CA$55K-CA$91K (Glassdoor est.)
# 273    CA$55K-CA$91K (Glassdoor est.)
# 279    CA$55K-CA$91K (Glassdoor est.)
# 280    CA$55K-CA$91K (Glassdoor est.)
# 283    CA$55K-CA$91K (Glassdoor est.)
# 289    CA$55K-CA$91K (Glassdoor est.)
# 290    CA$55K-CA$91K (Glassdoor est.)
# 303    CA$56K-CA$64K (Glassdoor est.)
# 305    CA$56K-CA$64K (Glassdoor est.)
# 311    CA$56K-CA$64K (Glassdoor est.)
# 313    CA$56K-CA$64K (Glassdoor est.)
# 316    CA$56K-CA$64K (Glassdoor est.)
# 320    CA$56K-CA$64K (Glassdoor est.)
#
#                                        Job Description  Rating  \
# 0    Listening to Albertans. Going deeper to unders...     3.6
# 6    To start the application process, you will nee...     4.4
# 7    Job Title\nAnalytics & Data Science Co-op/Inte...     3.9
# 8    Intelense being IBM business partner is focuse...    -1.0
# 9    Educator, Data Science\n\nBrainStation is a gl...     4.3
# 10   Application Deadline: May 31, 2020\n\nWhat you...     4.2
# 13   Req Id: 252188\n\nAt Bell, we do more than bui...     3.6
# 24   About Paytm Labs:\nAt Paytm Labs, we build tec...     3.8
# 35   Description:\n\nTalan is looking for a Data Sc...     4.2
# 36   Plotly is a high-growth, VC-backed data visual...     4.7
# 42   SCIENTIST- Research Institute\nThe Hospital fo...     4.1
# 44   Description de l'entreprise\n\nSia Partners ré...     4.0
# 45   Multiple locations\n\nKitchener, Ontario | Tor...     4.2
# 55   POSITION LOCATION: Toronto, ON\n\nPOSITION TIT...     4.0
# 61   Description:\nTalan is looking for a Data Scie...    -1.0
# 67   Unity powers over half of all the world's game...     4.8
# 73   The AlphaLayer team at AltaML is looking for a...     5.0
# 94   The AlphaLayer team at AltaML is looking for a...    -1.0
# 99   Company Overview\n\nH2O.ai is the open source ...     4.1
# 100  Summary\nPosted: Jan 8, 2020\nRole Number:2001...     4.1
# 103  Schedule Monday to Friday, 8:30 a.m. to 4:30 p...     4.4
# 120  Job Description :\nCANADA RESEARCH CHAIR TIER ...     4.0
# 146  Vous êtes unique, comme le sont votre parcours...     3.7
# 153  If you are an FCC employee, use your Workday p...     4.2
# 164  At Nylas, our mission is to empower the world ...     4.9
# 169  BFS, which has provided over $2BB in financing...     3.0
# 174  Amazon is building a world class advertising b...     3.9
# 175  Summary\nPosted: Apr 3, 2020\nRole Number:2001...     4.1
# 181  At Intact, insurance is not about things. Its ...     4.0
# 183  At Intact, insurance is not about things. Its ...     4.0
# 194  Requisition ID: 65995\n\nAt Scotiabank Digital...     3.6
# 202  Application Deadline: Ongoing\n\nWhat your day...     4.2
# 204  Do you want to be part of a team that builds s...     3.9
# 210  Accelerating the mass adoption of electric veh...     4.4
# 211  An exciting new start-up software company is l...    -1.0
# 215  On behalf of our client, we are searching for ...     2.8
# 222  At Loblaw Digital, we know that our customers ...     3.5
# 228  IQVIA™ is the leading human data science compa...     3.6
# 241  The Role\n\nData cloud is actively seeking a G...     3.4
# 242  Why work for us?\n\nAre you a forward-thinking...     3.9
# 244  Le moteur de notre succès a toujours été le pe...     2.9
# 247  Application Deadline: Ongoing\n\nWhat your day...     4.2
# 251  We seek biostatisticians with passion and exem...     4.1
# 256  Do you want to be part of a team that builds s...     3.9
# 261  Amazon is building a world class advertising b...     3.9
# 267  Accelerating the mass adoption of electric veh...     4.4
# 270  IQVIA is the leading human data science compan...     3.6
# 271  An exciting new start-up software company is l...    -1.0
# 273  IQVIA™ is the leading human data science compa...     3.6
# 279  On behalf of our client, we are searching for ...     2.8
# 280  IQVIA is the leading human data science compan...     3.6
# 283  Tatari, headquartered in San Francisco with of...     4.2
# 289  Do you want to join a new team of engineers wh...     3.9
# 290  At Loblaw Digital, we know that our customers ...     3.5
# 303  IQVIA™ is the leading human data science compa...     3.6
# 305  Who are we?\n\nFrom pioneer to leader in the s...     4.0
# 311  Our client\n\nOur client, a major Canadian con...     4.7
# 313  Position Overview:\n\nFront end engineers at H...     4.1
# 316  Who we are:\n\nWise Systems is a high-growth, ...     2.4
# 320  Req ID: 55672\nRegion: Americas\nCountry: Cana...     3.2
#
#                                   Company Name   Location  \
# 0                           ATB Financial\n3.6    Calgary
# 6                                  Google\n4.4    Toronto
# 7                                 TD Bank\n3.9    Toronto
# 8                                Intelense Inc    Toronto
# 9                            BrainStation\n4.3  Vancouver
# 10                              Clearbanc\n4.2    Toronto
# 13                            Bell Canada\n3.6    Toronto
# 24                             Paytm Labs\n3.8    Toronto
# 35                               Planaxis\n4.2   Montreal
# 36                                 Plotly\n4.7   Montreal
# 42                               SickKids\n4.1    Toronto
# 44                           Sia Partners\n4.0   Montreal
# 45                                    D2L\n4.2  Kitchener
# 55                Robarts Clinical Trials\n4.0    Toronto
# 61                        Planaxis | Groupaxis   Montreal
# 67                     Unity Technologies\n4.8   Montreal
# 73   AltaML Inc./Janalta Interactive Inc.\n5.0   Edmonton
# 94        AltaML Inc./Janalta Interactive Inc.   Edmonton
# 99                                 H2O.ai\n4.1     Ottawa
# 100                                 Apple\n4.1  Vancouver
# 103                   McMaster University\n4.4   Hamilton
# 120                University of Manitoba\n4.0   Winnipeg
# 146                    Sun Life Financial\n3.7   Waterloo
# 153                    Farm Credit Canada\n4.2     Regina
# 164                                 Nylas\n4.9    Toronto
# 169                           BFS Capital\n3.0    Toronto
# 174                                Amazon\n3.9    Toronto
# 175                                 Apple\n4.1  Vancouver
# 181                                Intact\n4.0    Toronto
# 183                                Intact\n4.0     Quebec
# 194                            Scotiabank\n3.6    Toronto
# 202                             Clearbanc\n4.2    Toronto
# 204                                Amazon\n3.9  Vancouver
# 210                            GBatteries\n4.4     Ottawa
# 211                       BlackBox Connections    Calgary
# 215       The Well - Creative Consultants\n2.8    Halifax
# 222                        Loblaw Digital\n3.5    Toronto
# 228                                 IQVIA\n3.6   Kirkland
# 241                             DATACLOUD\n3.4  Vancouver
# 242                               Flybits\n3.9    Toronto
# 244                             AspenTech\n2.9   Montreal
# 247                             Clearbanc\n4.2    Toronto
# 251                                 Roche\n4.1     Welwyn
# 256                                Amazon\n3.9  Vancouver
# 261                                Amazon\n3.9  Vancouver
# 267                            GBatteries\n4.4     Ottawa
# 270                                 IQVIA\n3.6     Ottawa
# 271                       BlackBox Connections    Calgary
# 273                                 IQVIA\n3.6   Kirkland
# 279       The Well - Creative Consultants\n2.8    Halifax
# 280                                 IQVIA\n3.6   Kirkland
# 283                                Tatari\n4.2    Toronto
# 289                                Amazon\n3.9    Toronto
# 290                        Loblaw Digital\n3.5    Toronto
# 303                                 IQVIA\n3.6   Kirkland
# 305                               Genetec\n4.0   Montreal
# 311                        ISG Search Inc\n4.7    Toronto
# 313                                h2o.ai\n4.1     Ottawa
# 316                          Wise Systems\n2.4   Montreal
# 320                             Celestica\n3.2    Toronto
#
#               Headquarters                     Size  Founded  \
# 0         Edmonton, Canada  5001 to 10000 employees     1938
# 6        Mountain View, CA         10000+ employees     1998
# 7          Toronto, Canada         10000+ employees     1855
# 8                       -1                       -1       -1
# 9             New York, NY      51 to 200 employees     2012
# 10         Toronto, Canada      51 to 200 employees     2015
# 13        Montreal, Canada         10000+ employees     1880
# 24         Toronto, Canada      51 to 200 employees     2014
# 35        Montreal, Canada      51 to 200 employees     1997
# 36        Montreal, Canada        1 to 50 employees       -1
# 42         Toronto, Canada  5001 to 10000 employees     1875
# 44           Paris, France   1001 to 5000 employees     1999
# 45       Kitchener, Canada    501 to 1000 employees     1999
# 55          London, Canada     201 to 500 employees     1986
# 61                      -1                       -1       -1
# 67       San Francisco, CA   1001 to 5000 employees     2005
# 73        Edmonton, Canada        1 to 50 employees     2018
# 94        Edmonton, Canada                  Unknown       -1
# 99       Mountain View, CA     201 to 500 employees     2011
# 100          Cupertino, CA         10000+ employees     1976
# 103       Hamilton, Canada  5001 to 10000 employees     1887
# 120       Winnipeg, Canada  5001 to 10000 employees     1877
# 146    Makati, Philippines     201 to 500 employees       -1
# 153         Regina, Canada   1001 to 5000 employees       -1
# 164      San Francisco, CA      51 to 200 employees     2013
# 169      Coral Springs, FL      51 to 200 employees     2002
# 174            Seattle, WA         10000+ employees     1994
# 175          Cupertino, CA         10000+ employees     1976
# 181        Toronto, Canada         10000+ employees       -1
# 183        Toronto, Canada         10000+ employees       -1
# 194        Toronto, Canada         10000+ employees     1832
# 202        Toronto, Canada      51 to 200 employees     2015
# 204            Seattle, WA         10000+ employees     1994
# 210         Ottawa, Canada        1 to 50 employees       -1
# 211                     -1                       -1       -1
# 215        Toronto, Canada      51 to 200 employees     2015
# 222        Toronto, Canada      51 to 200 employees       -1
# 228             Durham, NC         10000+ employees     2017
# 241       Bengaluru, India        1 to 50 employees       -1
# 242        Toronto, Canada      51 to 200 employees     2013
# 244            Bedford, MA   1001 to 5000 employees     1981
# 247        Toronto, Canada      51 to 200 employees     2015
# 251     Basel, Switzerland         10000+ employees     1896
# 256            Seattle, WA         10000+ employees     1994
# 261            Seattle, WA         10000+ employees     1994
# 267         Ottawa, Canada        1 to 50 employees       -1
# 270             Durham, NC         10000+ employees     2017
# 271                     -1                       -1       -1
# 273             Durham, NC         10000+ employees     2017
# 279        Toronto, Canada      51 to 200 employees     2015
# 280             Durham, NC         10000+ employees     2017
# 283      San Francisco, CA      51 to 200 employees     2016
# 289            Seattle, WA         10000+ employees     1994
# 290        Toronto, Canada      51 to 200 employees       -1
# 303             Durham, NC         10000+ employees     2017
# 305  Saint-Laurent, Canada   1001 to 5000 employees     1997
# 311        Toronto, Canada        1 to 50 employees     1990
# 313      Mountain View, CA     201 to 500 employees     2011
# 316            Fishers, IN        1 to 50 employees       -1
# 320        Toronto, Canada         10000+ employees     1994
#
#         Type of ownership  ...  age python_yn r_yn aws_yn  spark_yn  excel_yn  \
# 0       Company - Private  ...   82         1    0      0         0         0
# 6        Company - Public  ...   22         1    0      0         0         0
# 7        Company - Public  ...  165         1    0      0         0         1
# 8                      -1  ...   -1         1    0      0         1         0
# 9       Company - Private  ...    8         1    0      0         0         0
# 10      Company - Private  ...    5         1    0      0         0         0
# 13       Company - Public  ...  140         1    0      0         1         1
# 24      Company - Private  ...    6         1    0      0         0         1
# 35      Company - Private  ...   23         1    0      0         0         1
# 36      Company - Private  ...   -1         0    0      0         0         0
# 42       Company - Public  ...  145         0    0      0         0         1
# 44      Company - Private  ...   21         0    0      0         0         0
# 45      Company - Private  ...   21         0    0      0         0         0
# 55      Company - Private  ...   34         0    0      0         0         0
# 61                     -1  ...   -1         1    0      0         0         1
# 67      Company - Private  ...   15         1    0      1         1         1
# 73      Company - Private  ...    2         1    0      0         0         0
# 94      Company - Private  ...   -1         1    0      0         0         0
# 99      Company - Private  ...    9         1    0      1         1         1
# 100      Company - Public  ...   44         0    0      0         1         1
# 103  College / University  ...  133         0    0      0         0         1
# 120  College / University  ...  143         0    0      0         0         1
# 146     Company - Private  ...   -1         1    0      1         0         1
# 153     Company - Private  ...   -1         0    0      0         0         0
# 164     Company - Private  ...    7         1    0      1         1         0
# 169     Company - Private  ...   18         0    0      0         0         1
# 174      Company - Public  ...   26         0    0      0         0         0
# 175      Company - Public  ...   44         0    0      0         1         1
# 181      Company - Public  ...   -1         1    0      0         1         0
# 183      Company - Public  ...   -1         1    0      0         1         0
# 194      Company - Public  ...  188         1    0      0         0         0
# 202     Company - Private  ...    5         1    0      1         0         0
# 204      Company - Public  ...   26         0    0      1         0         1
# 210     Company - Private  ...   -1         1    0      0         0         0
# 211                    -1  ...   -1         1    0      0         0         1
# 215     Company - Private  ...    5         0    0      1         0         1
# 222      Company - Public  ...   -1         1    0      1         1         0
# 228      Company - Public  ...    3         1    0      0         0         1
# 241     Company - Private  ...   -1         1    0      0         0         0
# 242     Company - Private  ...    7         0    0      1         0         1
# 244      Company - Public  ...   39         0    0      0         0         1
# 247     Company - Private  ...    5         1    0      1         0         0
# 251      Company - Public  ...  124         1    0      0         0         0
# 256      Company - Public  ...   26         0    0      1         0         1
# 261      Company - Public  ...   26         0    0      0         0         0
# 267     Company - Private  ...   -1         1    0      0         0         0
# 270      Company - Public  ...    3         1    0      0         0         0
# 271                    -1  ...   -1         1    0      0         0         1
# 273      Company - Public  ...    3         0    0      0         0         0
# 279     Company - Private  ...    5         0    0      1         0         1
# 280      Company - Public  ...    3         0    0      0         0         0
# 283     Company - Private  ...    4         1    0      1         0         0
# 289      Company - Public  ...   26         0    0      0         0         0
# 290      Company - Public  ...   -1         1    0      1         1         0
# 303      Company - Public  ...    3         1    0      0         0         1
# 305     Company - Private  ...   23         1    0      0         0         1
# 311     Company - Private  ...   30         1    0      1         1         0
# 313     Company - Private  ...    9         1    0      0         0         0
# 316     Company - Private  ...   -1         1    0      0         0         1
# 320      Company - Public  ...   26         0    0      0         0         1
#
#      job_simp seniority desc_len  num_comp
# 0          na        jr     6525         3
# 6          na        jr     4401         3
# 7          na        jr     5024         3
# 8          na        jr     2220         0
# 9          na        jr     3727         0
# 10         na        jr     1662         0
# 13         na        jr     5321         3
# 24         na        jr     4131         0
# 35         na        jr     2137         0
# 36         na        jr     1280         0
# 42         na        jr     5927         0
# 44         na        jr     3614         0
# 45         na        jr     3472         2
# 55         na        jr     3575         3
# 61         na        jr     2090         0
# 67         na        jr    10431         3
# 73         na    senior     4116         0
# 94         na    senior     4115         0
# 99         na        jr     3305         0
# 100        na        jr     2553         3
# 103        na        jr     6959         0
# 120        na        jr     9884         0
# 146        na        jr     9307         0
# 153        na    senior     1577         0
# 164        na        jr     4147         0
# 169        na        jr     5054         0
# 174        na        jr     2438         3
# 175        na        jr     2992         3
# 181        na        jr     6267         3
# 183        na        jr     4654         3
# 194        na        jr     6292         1
# 202        na        jr     1209         0
# 204        na        jr     2513         3
# 210        na        jr     2833         0
# 211        na        jr     2609         0
# 215        na        jr     3059         0
# 222        na    senior     3576         0
# 228        na        jr     5367         3
# 241        na        jr     3046         0
# 242        na        jr     5416         0
# 244        na    senior     5564         2
# 247        na        jr     1209         0
# 251        na        jr     2338         3
# 256        na        jr     2513         3
# 261        na        jr     2663         3
# 267        na        jr     2833         0
# 270        na        jr     3386         3
# 271        na        jr     2609         0
# 273        na        jr     1018         3
# 279        na        jr     3059         0
# 280        na        jr     2282         3
# 283        na        jr     1553         0
# 289        na        jr     3336         3
# 290        na    senior     3576         0
# 303        na        jr     5367         3
# 305        na        jr     3739         0
# 311        na        jr     2871         0
# 313        na        jr     2706         0
# 316        na        jr     4364         0
# 320        na        jr     7113         1
#
# [60 rows x 30 columns]

# %%
## Job title and seniority 
df['seniority'] = df['Job Title'].apply(seniority)
df['seniority'].value_counts()
# Out:
# jr        667
# senior    343
# Name: seniority, dtype: int64

# %%
df['Location'].value_counts()
# Out:
# Toronto             341
# Montreal            227
# Vancouver           152
# Kirkland             48
# Brampton             27
# Ottawa               27
# Mississauga          23
# Winnipeg             21
# London               21
# Saskatoon            21
# Calgary              14
# Kitchener            11
# Canada                6
# Victoria              6
# Welwyn                5
# Halifax               5
# Waterloo              5
# Markham               4
# Edmonton              4
# Ontario               4
# Regina                3
# Moncton               3
# Richmond              3
# Kanata                2
# Saint John            2
# Windsor               2
# Hamilton              2
# Quebec                1
# Guelph                1
# Bedford               1
# Etobicoke             1
# Bolton                1
# Scarborough           1
# Dartmouth             1
# Oakville              1
# Cochin                1
# British Columbia      1
# Sparwood              1
# Burnaby               1
# Richmond Hill         1
# Saint-Hubert          1
# Laval                 1
# Thorold               1
# Acheson               1
# Newmarket             1
# North York            1
# Essex                 1
# Chatham               1
# Name: Location, dtype: int64

# %%
##  Job description length 
df['desc_len'] = df['Job Description'].apply(lambda x: len(x))
df['desc_len']
# Out:
# 0       6525
# 1       2946
# 2       4791
# 3       5709
# 4       3120
#         ...
# 1005    5519
# 1006    3490
# 1007    4088
# 1008    2493
# 1009    2821
# Name: desc_len, Length: 1010, dtype: int64

# %%
##  Competitor count
df['num_comp'] = df['Competitors'].apply(lambda x: len(x.split(',')) if x != '-1' else 0)
df['num_comp'].value_counts()
# Out:
# 0    685
# 3    282
# 2     35
# 1      8
# Name: num_comp, dtype: int64

# %%
df['Competitors']
# Out:
# 0                 TD, RBC, Scotiabank
# 1          ESPN, Turner Sports, Yahoo
# 2               ADP, Workday, Paychex
# 3                                  -1
# 4       MindGeek, Shopify, Lightspeed
#                     ...
# 1005                               -1
# 1006                               -1
# 1007                               -1
# 1008                               -1
# 1009                               -1
# Name: Competitors, Length: 1010, dtype: object

# %%
df['company_txt'] = df['company_txt'].apply(lambda x: x.replace('\n',''))
df['company_txt']
# Out:
# 0                ATB Financial
# 1                     theScore
# 2                     Ceridian
# 3                       RideCo
# 4                       MavTek
#                  ...
# 1005                  agileDSS
# 1006      Clir Renewables Inc.
# 1007    University of Manitoba
# 1008     Visier Solutions Inc.
# 1009          Fusion Analytics
# Name: company_txt, Length: 1010, dtype: object

# %%
df.describe()
# Out:
#             Rating      Founded   min_salary   max_salary   avg_salary  \
# count  1010.000000  1010.000000  1010.000000  1010.000000  1010.000000
# mean      3.604455  1519.754455    53.297030    73.198020    63.247525
# std       1.440931   847.794538    18.372613    21.496085    19.748120
# min      -1.000000    -1.000000    41.000000    59.000000    50.000000
# 25%       3.500000  1861.000000    41.000000    59.000000    50.000000
# 50%       3.900000  1994.000000    41.000000    59.000000    50.000000
# 75%       4.400000  2008.000000    66.000000    91.000000    80.000000
# max       5.000000  2018.000000   101.000000   123.000000   112.000000
#
#         same_state          age    python_yn         r_yn       aws_yn  \
# count  1010.000000  1010.000000  1010.000000  1010.000000  1010.000000
# mean      0.400990    21.772277     0.570297     0.001980     0.269307
# std       0.490342    36.066611     0.495279     0.044477     0.443819
# min       0.000000    -1.000000     0.000000     0.000000     0.000000
# 25%       0.000000     2.000000     0.000000     0.000000     0.000000
# 50%       0.000000    12.000000     1.000000     0.000000     0.000000
# 75%       1.000000    26.000000     1.000000     0.000000     1.000000
# max       1.000000   208.000000     1.000000     1.000000     1.000000
#
#           spark_yn     excel_yn      desc_len     num_comp
# count  1010.000000  1010.000000   1010.000000  1010.000000
# mean      0.240594     0.464356   4160.500000     0.914851
# std       0.427656     0.498975   1776.144126     1.350651
# min       0.000000     0.000000    459.000000     0.000000
# 25%       0.000000     0.000000   2856.000000     0.000000
# 50%       0.000000     0.000000   3801.000000     0.000000
# 75%       0.000000     1.000000   4784.250000     3.000000
# max       1.000000     1.000000  12233.000000     3.000000

# %%
df['Rating'].hist()

# %%
df['avg_salary'].hist()

# %%
df['age'].hist()

# %%
df['desc_len'].hist()

# %%
df.boxplot(column= ['age', 'avg_salary', 'Rating'])

# %%
df.boxplot(column= 'Rating')

# %%
df.boxplot(column= 'avg_salary')

# %%
df['avg_salary'].skew()
# Out:
# 1.182221045792802

# %%
df['desc_len'].skew()
# Out:
# 1.0927171693543345

# %%
sal_log = np.log(df['avg_salary'])
sal_log.skew()
# Out:
# 1.002703130844576

# %%
sal_log.hist()

# %%
df['age'].skew()
# Out:
# 2.90481091690608

# %%
df['avg_salary'].skew()
# Out:
# 1.182221045792802

# %%
df[['age', 'avg_salary', 'Rating', 'desc_len']].corr()
# Out:
#                  age  avg_salary    Rating  desc_len
# age         1.000000    0.091740  0.085272  0.098301
# avg_salary  0.091740    1.000000 -0.194140 -0.081637
# Rating      0.085272   -0.194140  1.000000  0.130638
# desc_len    0.098301   -0.081637  0.130638  1.000000

# %%
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(df[['age','avg_salary','Rating','desc_len','num_comp']].corr(),vmax=.3, center=0, cmap=cmap,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
df_cat = df[['Location', 'Headquarters', 'Size','Type of ownership', 'Industry', 'Sector', 'Revenue', 'company_txt', 'hq_short','same_state', 'python_yn', 'r_yn',
       'spark_yn', 'aws_yn', 'excel_yn', 'job_simp', 'seniority']]

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'min_salary', 'max_salary', 'avg_salary', 'company_txt', 'hq_short',
#        'same_state', 'age', 'python_yn', 'r_yn', 'aws_yn', 'spark_yn',
#        'excel_yn', 'job_simp', 'seniority', 'desc_len', 'num_comp'],
#       dtype='object')

# %%
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    print("graph for %s: total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Location: total = 48
# graph for Headquarters: total = 116
# graph for Size: total = 9
# graph for Type of ownership: total = 12
# graph for Industry: total = 47
# graph for Sector: total = 21
# graph for Revenue: total = 14
# graph for company_txt: total = 280
# graph for hq_short: total = 115
# graph for same_state: total = 2
# graph for python_yn: total = 2
# graph for r_yn: total = 2
# graph for spark_yn: total = 2
# graph for aws_yn: total = 2
# graph for excel_yn: total = 2
# graph for job_simp: total = 7
# graph for seniority: total = 2
